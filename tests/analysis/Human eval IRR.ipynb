# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/conv-trs/ecir-2026/human-eval/survey_parsed.csv")

# %%
df
# Out:
#                 query_id                                              query  \
# 0    c_p_0_pop_high_easy  Suggest popular European cities with outdoor a...
# 1    c_p_0_pop_high_easy  Suggest popular European cities with outdoor a...
# 2    c_p_0_pop_high_easy  Suggest popular European cities with outdoor a...
# 3    c_p_0_pop_high_easy  Suggest popular European cities with outdoor a...
# 4    c_p_0_pop_high_easy  Suggest popular European cities with outdoor a...
# ..                   ...                                                ...
# 465                  NaN                                                NaN
# 466                  NaN                                                NaN
# 467                  NaN                                                NaN
# 468                  NaN                                                NaN
# 469                  NaN                                                NaN
#
# ...

# %%
df.columns
# Out:
# Index(['query_id', 'query', 'annotator', 'relevance', 'popularity',
#        'diversity', 'sustainability', 'feedback'],
#       dtype='object')

# %%
df.annotator.unique()
# Out:
# array(['Wolfgang', 'Yas', 'Ewald', 'Tejas Srinivasan', 'Comet [AI]',
#        'Dana Marti', nan], dtype=object)
