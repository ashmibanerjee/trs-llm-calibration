# %%
import pandas as pd
import json

# %%
models = ["gpt5", "gemini", "deepseek"]

# %%
for model in models:
    file_path = f"../../data/conv-trs/ecir-2026/direct-reasoner/cleaned/"
    calibrated_file_name = f"calibration_{model}_evals_cleaned_v1.csv"
    v1_eval_file_name = f"{model}_evals_cleaned_v1.csv"
    calibrated_df = pd.read_csv(file_path + calibrated_file_name)
    v1_df = pd.read_csv(file_path + v1_eval_file_name)
    print(f"Model: {model}")
